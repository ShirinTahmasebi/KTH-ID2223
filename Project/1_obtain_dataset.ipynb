# %% [markdown]
# <a href="https://colab.research.google.com/github/ShirinTahmasebi/KTH-ID2223/blob/main/1_obtain_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
! pip install transformers
! pip install openai

# %%
DATASET_PATH = '/content/drive/MyDrive/Embedding with GPT-3/input/Reviews.csv'
OPEN_AI_API_KEY = '/content/drive/MyDrive/Embedding with GPT-3/input/openai_api_key.txt'
OPEN_AI_REQUEST_LIMIT = 50

# %%
import pandas as pd

## 1. Load the dataset

df = pd.read_csv(DATASET_PATH, index_col=0)
df = df[['Time', 'ProductId', 'UserId', 'Score', 'Summary', 'Text']]
df = df.dropna()
df['combined'] = "Title: " + df.Summary.str.strip() + "; Content: " + df.Text.str.strip()
df.head(2)
# Out:
#           Time   ProductId          UserId  Score                Summary  \
# Id
# 1   1303862400  B001E4KFG0  A3SGXH7AUHU8GW      5  Good Quality Dog Food
# 2   1346976000  B00813GRG4  A1D87F6ZCVE5NK      1      Not as Advertised
#
#                                                  Text  \
# Id
# 1   I have bought several of the Vitality canned d...
# 2   Product arrived labeled as Jumbo Salted Peanut...
#
#                                              combined
# Id
# 1   Title: Good Quality Dog Food; Content: I have ...
# 2   Title: Not as Advertised; Content: Product arr...

# %%
# Subsample to 1k most recent reviews and remove samples that are too long
df = df.sort_values('Time').tail(1_100)
df.drop('Time', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
from transformers import GPT2TokenizerFast
tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

# %%
# Remove reviews that are too long
df['n_tokens'] = df.combined.apply(lambda x: len(tokenizer.encode(x)))
df = df[df.n_tokens<2000].tail(1_000)
len(df)
# Out:
# 1000

# %%
### 2. Get embeddings and save them for future reuse

#%%
import openai
from openai.embeddings_utils import get_embedding

openai.api_key = open(OPEN_AI_API_KEY).readlines()[0]

# %%
engines = \
[
  'text-similarity-davinci-001',
  # 'text-similarity-ada-001',
  'text-similarity-babbage-001',
  'text-similarity-curie-001',
  # 'code-search-ada-code-001',
  # 'code-search-babbage-code-001'
]

# %%
result_column_names = []

for item in engines:
  result_column_names.append('embedding_' + item)
  result_column_names.append('reduced_x_' + item)
  result_column_names.append('reduced_y_' + item)

# %%
def create_embedding_for_engine(engine:str, last_query_time=0):
  import time
  import math
  from datetime import datetime

  expected_number_of_iterations = math.ceil(len(df) / OPEN_AI_REQUEST_LIMIT)

  result_series = pd.Series([])

  for i in range(expected_number_of_iterations):
    while last_query_time and time.time() - last_query_time < 60:
      continue

    lowerbound_index = i * OPEN_AI_REQUEST_LIMIT
    upperbound_index = lowerbound_index + OPEN_AI_REQUEST_LIMIT

    print('Current time is: ', datetime.now().strftime('%H:%M:%S'), ' - From [{},{})'.format(lowerbound_index, upperbound_index))
    temp_result_series = df.iloc[lowerbound_index: upperbound_index].combined.apply(lambda x: get_embedding(x, engine=engine))
    result_series = result_series.append(temp_result_series)

    last_query_time = time.time()
  
  return result_series, last_query_time

# %%
df_result = pd.DataFrame(columns=result_column_names)

# %%
for item in engines:
  # df_result['embedding_' + item], last_query_time = create_embedding_for_engine(item, last_query_time)
  df_result['embedding_' + item] = df.combined.apply(lambda x: get_embedding(x, engine=item))
  # break
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     406                 try:
# --> 407                     result = fn(*args, **kwargs)
#     408                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.7/dist-packages/openai/embeddings_utils.py in get_embedding(text, engine)
#      22
# ---> 23     return openai.Embedding.create(input=[text], engine=engine)["data"][0]["embedding"]
#      24
#
# /usr/local/lib/python3.7/dist-packages/openai/api_resources/embedding.py in create(cls, *args, **kwargs)
#      39             try:
# ---> 40                 response = super().create(*args, **kwargs)
#      41
#
# /usr/local/lib/python3.7/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     105             stream=stream,
# --> 106             request_id=request_id,
#     107         )
#
# /usr/local/lib/python3.7/dist-packages/openai/api_requestor.py in request(self, method, url, params, headers, files, stream, request_id)
#     121         )
# --> 122         resp, got_stream = self._interpret_response(result, stream)
#     123         return resp, got_stream, self.api_key
#
# /usr/local/lib/python3.7/dist-packages/openai/api_requestor.py in _interpret_response(self, result, stream)
#     329                 self._interpret_response_line(
# --> 330                     result.content, result.status_code, result.headers, stream=False
#     331                 ),
#
# /usr/local/lib/python3.7/dist-packages/openai/api_requestor.py in _interpret_response_line(self, rbody, rcode, rheaders, stream)
#     362             raise self.handle_error_response(
# --> 363                 rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     364             )
#
# RateLimitError: you exceeded your current quota, please check your plan and billing details
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-34-dc3010176f5b> in <module>()
#       1 for item in engines:
#       2   # df_result['embedding_' + item], last_query_time = create_embedding_for_engine(item, last_query_time)
# ----> 3   df_result['embedding_' + item] = df.combined.apply(lambda x: get_embedding(x, engine=item))
#       4   # break
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-34-dc3010176f5b> in <lambda>(x)
#       1 for item in engines:
#       2   # df_result['embedding_' + item], last_query_time = create_embedding_for_engine(item, last_query_time)
# ----> 3   df_result['embedding_' + item] = df.combined.apply(lambda x: get_embedding(x, engine=item))
#       4   # break
#
# /usr/local/lib/python3.7/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     322         @functools.wraps(f)
#     323         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 324             return self(f, *args, **kw)
#     325
#     326         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.7/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     402         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     403         while True:
# --> 404             do = self.iter(retry_state=retry_state)
#     405             if isinstance(do, DoAttempt):
#     406                 try:
#
# /usr/local/lib/python3.7/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     359             if self.reraise:
#     360                 raise retry_exc.reraise()
# --> 361             raise retry_exc from fut.exception()
#     362
#     363         if self.wait:
#
# RetryError: RetryError[<Future at 0x7fe343b52590 state=finished raised RateLimitError>]

# %%
df_result
# Out:
#                     embedding_text-similarity-davinci-001  \
# 284932  [-0.005729738622903824, 0.002782381372526288, ...
# 220697  [-0.015217021107673645, 0.007462559267878532, ...
# 107908  [-0.004584628622978926, 0.01346516516059637, -...
# 107800  [0.0012591804843395948, 0.00389345595613122, -...
# 205313  [-0.0032210019417107105, 0.0040468997322022915...
# ...                                                   ...
# 7178    [-0.0005286579835228622, 0.0024464321322739124...
# 401972  [-0.0002831067831721157, -0.003314807778224349...
# 462088  [-0.0036534518003463745, 0.0004380333120934665...
# 267549  [-0.005907019134610891, 0.0012909695506095886,...
# 542497  [-0.008624717593193054, 0.004451978951692581, ...
#
#        reduced_x_text-similarity-davinci-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        reduced_y_text-similarity-davinci-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#                         embedding_text-similarity-ada-001  \
# 284932  [0.01860060915350914, -0.015613649971783161, -...
# 220697  [0.018258072435855865, 0.03005059063434601, -0...
# 107908  [-0.0005673975683748722, -0.012302356772124767...
# 107800  [0.01373705267906189, 0.053661659359931946, -0...
# 205313  [0.021258626133203506, 0.007491868454962969, -...
# ...                                                   ...
# 7178    [-0.016586609184741974, 0.03342374041676521, -...
# 401972  [-0.016825618222355843, -0.00798442680388689, ...
# 462088  [0.00622323714196682, 0.008891819044947624, -0...
# 267549  [0.012264199554920197, 0.022083846852183342, -...
# 542497  [0.013289941474795341, 0.000356678559910506, -...
#
#        reduced_x_text-similarity-ada-001 reduced_y_text-similarity-ada-001  \
# 284932                               NaN                               NaN
# 220697                               NaN                               NaN
# 107908                               NaN                               NaN
# 107800                               NaN                               NaN
# 205313                               NaN                               NaN
# ...                                  ...                               ...
# 7178                                 NaN                               NaN
# 401972                               NaN                               NaN
# 462088                               NaN                               NaN
# 267549                               NaN                               NaN
# 542497                               NaN                               NaN
#
#        embedding_text-similarity-babbage-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        reduced_x_text-similarity-babbage-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        reduced_y_text-similarity-babbage-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        embedding_text-similarity-curie-001  \
# 284932                                 NaN
# 220697                                 NaN
# 107908                                 NaN
# 107800                                 NaN
# 205313                                 NaN
# ...                                    ...
# 7178                                   NaN
# 401972                                 NaN
# 462088                                 NaN
# 267549                                 NaN
# 542497                                 NaN
#
#        reduced_x_text-similarity-curie-001  \
# 284932                                 NaN
# 220697                                 NaN
# 107908                                 NaN
# 107800                                 NaN
# 205313                                 NaN
# ...                                    ...
# 7178                                   NaN
# 401972                                 NaN
# 462088                                 NaN
# 267549                                 NaN
# 542497                                 NaN
#
#        reduced_y_text-similarity-curie-001 embedding_code-search-ada-code-001  \
# 284932                                 NaN                                NaN
# 220697                                 NaN                                NaN
# 107908                                 NaN                                NaN
# 107800                                 NaN                                NaN
# 205313                                 NaN                                NaN
# ...                                    ...                                ...
# 7178                                   NaN                                NaN
# 401972                                 NaN                                NaN
# 462088                                 NaN                                NaN
# 267549                                 NaN                                NaN
# 542497                                 NaN                                NaN
#
#        reduced_x_code-search-ada-code-001 reduced_y_code-search-ada-code-001  \
# 284932                                NaN                                NaN
# 220697                                NaN                                NaN
# 107908                                NaN                                NaN
# 107800                                NaN                                NaN
# 205313                                NaN                                NaN
# ...                                   ...                                ...
# 7178                                  NaN                                NaN
# 401972                                NaN                                NaN
# 462088                                NaN                                NaN
# 267549                                NaN                                NaN
# 542497                                NaN                                NaN
#
#        embedding_code-search-babbage-code-001  \
# 284932                                    NaN
# 220697                                    NaN
# 107908                                    NaN
# 107800                                    NaN
# 205313                                    NaN
# ...                                       ...
# 7178                                      NaN
# 401972                                    NaN
# 462088                                    NaN
# 267549                                    NaN
# 542497                                    NaN
#
#        reduced_x_code-search-babbage-code-001  \
# 284932                                    NaN
# 220697                                    NaN
# 107908                                    NaN
# 107800                                    NaN
# 205313                                    NaN
# ...                                       ...
# 7178                                      NaN
# 401972                                    NaN
# 462088                                    NaN
# 267549                                    NaN
# 542497                                    NaN
#
#        reduced_y_code-search-babbage-code-001
# 284932                                    NaN
# 220697                                    NaN
# 107908                                    NaN
# 107800                                    NaN
# 205313                                    NaN
# ...                                       ...
# 7178                                      NaN
# 401972                                    NaN
# 462088                                    NaN
# 267549                                    NaN
# 542497                                    NaN
#
# [1000 rows x 18 columns]

# %%
df_result['label'] = df['Score']

# %%
import os

def check_dir(file_name):
    directory = os.path.dirname(file_name)
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
check_dir('output/result_Reviews.csv')
df_result.to_csv('output/result_Reviews.csv')

# %%
import os
os.system('cp -r "/content/output/" "/content/drive/MyDrive/Embedding with GPT-3/"')
# Out:
# 0

# %%
df_result
# Out:
#                     embedding_text-similarity-davinci-001  \
# 284932  [-0.005729738622903824, 0.002782381372526288, ...
# 220697  [-0.015217021107673645, 0.007462559267878532, ...
# 107908  [-0.004584628622978926, 0.01346516516059637, -...
# 107800  [0.0012591804843395948, 0.00389345595613122, -...
# 205313  [-0.0032210019417107105, 0.0040468997322022915...
# ...                                                   ...
# 7178    [-0.0005286579835228622, 0.0024464321322739124...
# 401972  [-0.0002831067831721157, -0.003314807778224349...
# 462088  [-0.0036534518003463745, 0.0004380333120934665...
# 267549  [-0.005907019134610891, 0.0012909695506095886,...
# 542497  [-0.008624717593193054, 0.004451978951692581, ...
#
#        reduced_x_text-similarity-davinci-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        reduced_y_text-similarity-davinci-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#                         embedding_text-similarity-ada-001  \
# 284932  [0.01860060915350914, -0.015613649971783161, -...
# 220697  [0.018258072435855865, 0.03005059063434601, -0...
# 107908  [-0.0005673975683748722, -0.012302356772124767...
# 107800  [0.01373705267906189, 0.053661659359931946, -0...
# 205313  [0.021258626133203506, 0.007491868454962969, -...
# ...                                                   ...
# 7178    [-0.016586609184741974, 0.03342374041676521, -...
# 401972  [-0.016825618222355843, -0.00798442680388689, ...
# 462088  [0.00622323714196682, 0.008891819044947624, -0...
# 267549  [0.012264199554920197, 0.022083846852183342, -...
# 542497  [0.013289941474795341, 0.000356678559910506, -...
#
#        reduced_x_text-similarity-ada-001 reduced_y_text-similarity-ada-001  \
# 284932                               NaN                               NaN
# 220697                               NaN                               NaN
# 107908                               NaN                               NaN
# 107800                               NaN                               NaN
# 205313                               NaN                               NaN
# ...                                  ...                               ...
# 7178                                 NaN                               NaN
# 401972                               NaN                               NaN
# 462088                               NaN                               NaN
# 267549                               NaN                               NaN
# 542497                               NaN                               NaN
#
#        embedding_text-similarity-babbage-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        reduced_x_text-similarity-babbage-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        reduced_y_text-similarity-babbage-001  \
# 284932                                   NaN
# 220697                                   NaN
# 107908                                   NaN
# 107800                                   NaN
# 205313                                   NaN
# ...                                      ...
# 7178                                     NaN
# 401972                                   NaN
# 462088                                   NaN
# 267549                                   NaN
# 542497                                   NaN
#
#        embedding_text-similarity-curie-001  \
# 284932                                 NaN
# 220697                                 NaN
# 107908                                 NaN
# 107800                                 NaN
# 205313                                 NaN
# ...                                    ...
# 7178                                   NaN
# 401972                                 NaN
# 462088                                 NaN
# 267549                                 NaN
# 542497                                 NaN
#
#        reduced_x_text-similarity-curie-001  \
# 284932                                 NaN
# 220697                                 NaN
# 107908                                 NaN
# 107800                                 NaN
# 205313                                 NaN
# ...                                    ...
# 7178                                   NaN
# 401972                                 NaN
# 462088                                 NaN
# 267549                                 NaN
# 542497                                 NaN
#
#        reduced_y_text-similarity-curie-001 embedding_code-search-ada-code-001  \
# 284932                                 NaN                                NaN
# 220697                                 NaN                                NaN
# 107908                                 NaN                                NaN
# 107800                                 NaN                                NaN
# 205313                                 NaN                                NaN
# ...                                    ...                                ...
# 7178                                   NaN                                NaN
# 401972                                 NaN                                NaN
# 462088                                 NaN                                NaN
# 267549                                 NaN                                NaN
# 542497                                 NaN                                NaN
#
#        reduced_x_code-search-ada-code-001 reduced_y_code-search-ada-code-001  \
# 284932                                NaN                                NaN
# 220697                                NaN                                NaN
# 107908                                NaN                                NaN
# 107800                                NaN                                NaN
# 205313                                NaN                                NaN
# ...                                   ...                                ...
# 7178                                  NaN                                NaN
# 401972                                NaN                                NaN
# 462088                                NaN                                NaN
# 267549                                NaN                                NaN
# 542497                                NaN                                NaN
#
#        embedding_code-search-babbage-code-001  \
# 284932                                    NaN
# 220697                                    NaN
# 107908                                    NaN
# 107800                                    NaN
# 205313                                    NaN
# ...                                       ...
# 7178                                      NaN
# 401972                                    NaN
# 462088                                    NaN
# 267549                                    NaN
# 542497                                    NaN
#
#        reduced_x_code-search-babbage-code-001  \
# 284932                                    NaN
# 220697                                    NaN
# 107908                                    NaN
# 107800                                    NaN
# 205313                                    NaN
# ...                                       ...
# 7178                                      NaN
# 401972                                    NaN
# 462088                                    NaN
# 267549                                    NaN
# 542497                                    NaN
#
#        reduced_y_code-search-babbage-code-001  label
# 284932                                    NaN      5
# 220697                                    NaN      1
# 107908                                    NaN      4
# 107800                                    NaN      3
# 205313                                    NaN      5
# ...                                       ...    ...
# 7178                                      NaN      5
# 401972                                    NaN      5
# 462088                                    NaN      5
# 267549                                    NaN      5
# 542497                                    NaN      5
#
# [1000 rows x 19 columns]
